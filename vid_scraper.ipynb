# %%
import pandas as pd
import yt_dlp
import uuid
import os
import time

# Function to scrape channel and video metadata and download videos
def scrape_channel_videos(channel_urls, duration_limit=98, download_folder='downloaded_videos'):
    os.makedirs(download_folder, exist_ok=True)

    data = []

    ydl_opts_metadata = {
        'quiet': True,
        'extract_flat': False,
        'skip_download': True,
        'ignoreerrors': True,
        'force_generic_extractor': False,
        'force_ipv4': True,
        'cookiefile': '/home/mhammed/Desktop/tech_projects/video_evaluator/www.youtube.com_cookies.txt',
    }

    with yt_dlp.YoutubeDL(ydl_opts_metadata) as ydl:
        print("Starting channel scraping...")
        for channel_url in channel_urls:
            print(f"Processing channel: {channel_url}")
            try:
                time.sleep(5)
                channel_info = ydl.extract_info(channel_url, download=False)
                channel_data = {
                    'channel_name': channel_info.get('channel'),
                    'channel_url': channel_info.get('channel_url'),
                    'channel_description': channel_info.get('description'),
                    'channel_subscriber_count': channel_info.get('channel_follower_count'),
                    'channel_join_date': channel_info.get('channel_created'),
                }
                print(f"Processing channel: {channel_info.get('channel')}")

                for entry in channel_info.get('entries', []):
                    time.sleep(5)
                    print(f"Processing video: {entry.get('title')}")
                    if entry and entry.get('duration', 0) <= duration_limit and entry.get('view_count') >= channel_info.get('channel_follower_count'):
                        video_comments = [c.get('text') for c in entry.get('comments', [])] if entry.get('comments') else []

                        video_id = str(uuid.uuid4())
                        downloaded = False
                        resolution = None

                        ydl_opts_download = {
                            'quiet': True,
                            'ignoreerrors': True,
                            'format': 'bestvideo[height<=720]+bestaudio/best[height<=720]',
                            'outtmpl': f'{download_folder}/{video_id}.%(ext)s',
                        }
                        print(f"Downloading video {entry.get('webpage_url')}")

                        time.sleep(5)
                        with yt_dlp.YoutubeDL(ydl_opts_download) as ydl_download:
                            try:
                                info_dict = ydl_download.extract_info(entry.get('webpage_url'), download=True)
                                downloaded = True if info_dict else False
                                resolution = info_dict.get('height') if info_dict else None
                                print(f"Downloaded video {entry.get('webpage_url')}")
                            except Exception as download_error:
                                print(f"Error downloading video {entry.get('webpage_url')}: {download_error}")
                            
                        video_data = {
                            'id': video_id,
                            'video_title': entry.get('title'),
                            'video_description': entry.get('description'),
                            'video_url': entry.get('webpage_url'),
                            'video_publish_date': entry.get('upload_date'),
                            'video_tags': entry.get('tags'),
                            'views': entry.get('view_count'),
                            'comments': video_comments,
                            'comment_count': entry.get('comment_count'),
                            'likes': entry.get('like_count'),
                            'dislikes': entry.get('dislike_count'),
                            'resolution': resolution,
                            'downloaded': downloaded,
                            **channel_data
                        }
                        
                        data.append(video_data)
                        print(f"Processed video {entry.get('webpage_url')}")

            except Exception as e:
                print(f"Error processing {channel_url}: {e}")

    return pd.DataFrame(data)


# List of YouTube channel URLs (replace with your URLs)
channel_urls = [
    'https://www.youtube.com/channel/UCNhxq7He5p-_FdBh0OaxcQg', #https://www.youtube.com/@Nike
    'https://www.youtube.com/channel/UCuLUOxd7ezJ8c6NSLBNRRfg', #https://www.youtube.com/@adidas
    'https://www.youtube.com/channel/UCbpUSVxiBSjc0CHm0ksuJgw', #https://www.youtube.com/@McDonalds
    'https://www.youtube.com/channel/UCYFQ33UIPERYx8-ZHucZbDA', #https://www.youtube.com/@Apple
    'https://www.youtube.com/channel/UCnEdfCdbxJJ9ouWKLSRCRRw', #https://www.youtube.com/@Samsung
    'https://www.youtube.com/channel/UC8VddvuHJzIj__Ud0rY2_ww', #https://www.youtube.com/@redbull
    'https://www.youtube.com/channel/UC-WMwOzgFdvvGVLB1EZ-n-w', #https://www.youtube.com/@GoPro
    'https://www.youtube.com/channel/UC1xnncYc7586km_rIYQLtLQ', #https://www.youtube.com/@Uber
    'https://www.youtube.com/channel/UCGie8GMlUo3kBKIopdvumVQ', #https://www.youtube.com/@Netflix
    'https://www.youtube.com/channel/UCIrgJInjLS2BhlHOMDW7v0g', #https://www.youtube.com/@disney
    'https://www.youtube.com/channel/UC9G8DcGtPfHsVEfUTM_TjEw', #https://www.youtube.com/@intel
    'https://www.youtube.com/channel/UCxGq825hl0AHP18I9-JGKgg', #https://www.youtube.com/@amazon
    'https://www.youtube.com/channel/UCnba_sSOe_umiHCpYYvRCqQ', #https://www.youtube.com/@Microsoft
    'https://www.youtube.com/channel/UCDCIVTeg-_V-xmFV8kAkblg', #https://www.youtube.com/@Sony
    ]

# Scrape, download videos, and save to CSV
df = scrape_channel_videos(channel_urls)
df.to_csv('youtube_videos_metadata.csv', index=False)

# Display dataframe
df.head()
# Out:
# Starting channel scraping...
# Processing channel: https://www.youtube.com/channel/UCuLUOxd7ezJ8c6NSLBNRRfg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 112
#      94 channel_urls = [
#      95
#      96     'https://www.youtube.com/channel/UCuLUOxd7ezJ8c6NSLBNRRfg', #https://www.youtube.com/@adidas
#    (...)    108     'https://www.youtube.com/channel/UCDCIVTeg-_V-xmFV8kAkblg', #https://www.youtube.com/@Sony
#     109     ]
#     111 # Scrape, download videos, and save to CSV
# --> 112 df = scrape_channel_videos(channel_urls)
#     113 df.to_csv('youtube_videos_metadata.csv', index=False)
#     115 # Display dataframe
#
# Cell In[3], line 29, in scrape_channel_videos(channel_urls, duration_limit, download_folder)
#      27 try:
#      28     time.sleep(5)
# ---> 29     channel_info = ydl.extract_info(channel_url, download=False)
#      30     channel_data = {
#      31         'channel_name': channel_info.get('channel'),
#      32         'channel_url': channel_info.get('channel_url'),
#    (...)     35         'channel_join_date': channel_info.get('channel_created'),
#      36     }
#      37     print(f"Processing channel: {channel_info.get('channel')}")
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1642, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1640             raise ExistingVideoReached
#    1641         break
# -> 1642     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1643 else:
#    1644     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1653, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1651 while True:
#    1652     try:
# -> 1653         return func(self, *args, **kwargs)
#    1654     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1655         raise
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1809, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1807 if process:
#    1808     self._wait_for_video(ie_result)
# -> 1809     return self.process_ie_result(ie_result, download, extra_info)
#    1810 else:
#    1811     return ie_result
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1938, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1936 self._sanitize_thumbnails(ie_result)
#    1937 try:
# -> 1938     return self.__process_playlist(ie_result, download)
#    1939 finally:
#    1940     self._playlist_level -= 1
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:2086, in YoutubeDL.__process_playlist(self, ie_result, download)
#    2080     continue
#    2082 self.to_screen(
#    2083     f'[download] Downloading item {self._format_screen(i + 1, self.Styles.ID)} '
#    2084     f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
# -> 2086 entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2087     'playlist_index': playlist_index,
#    2088     'playlist_autonumber': i + 1,
#    2089 }, extra))
#    2090 if not entry_result:
#    2091     failures += 1
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1653, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1651 while True:
#    1652     try:
# -> 1653         return func(self, *args, **kwargs)
#    1654     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1655         raise
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:2118, in YoutubeDL.__process_iterable_entry(self, entry, download, extra_info)
#    2116 @_handle_extraction_exceptions
#    2117 def __process_iterable_entry(self, entry, download, extra_info):
# -> 2118     return self.process_ie_result(
#    2119         entry, download=download, extra_info=extra_info)
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1938, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1936 self._sanitize_thumbnails(ie_result)
#    1937 try:
# -> 1938     return self.__process_playlist(ie_result, download)
#    1939 finally:
#    1940     self._playlist_level -= 1
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:2086, in YoutubeDL.__process_playlist(self, ie_result, download)
#    2080     continue
#    2082 self.to_screen(
#    2083     f'[download] Downloading item {self._format_screen(i + 1, self.Styles.ID)} '
#    2084     f'of {self._format_screen(n_entries, self.Styles.EMPHASIS)}')
# -> 2086 entry_result = self.__process_iterable_entry(entry, download, collections.ChainMap({
#    2087     'playlist_index': playlist_index,
#    2088     'playlist_autonumber': i + 1,
#    2089 }, extra))
#    2090 if not entry_result:
#    2091     failures += 1
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1653, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1651 while True:
#    1652     try:
# -> 1653         return func(self, *args, **kwargs)
#    1654     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1655         raise
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:2118, in YoutubeDL.__process_iterable_entry(self, entry, download, extra_info)
#    2116 @_handle_extraction_exceptions
#    2117 def __process_iterable_entry(self, entry, download, extra_info):
# -> 2118     return self.process_ie_result(
#    2119         entry, download=download, extra_info=extra_info)
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1888, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1884     return ie_result
#    1885 elif result_type == 'url':
#    1886     # We have to add extra_info to the results because it may be
#    1887     # contained in a playlist
# -> 1888     return self.extract_info(
#    1889         ie_result['url'], download,
#    1890         ie_key=ie_result.get('ie_key'),
#    1891         extra_info=extra_info)
#    1892 elif result_type == 'url_transparent':
#    1893     # Use the information from the embedding page
#    1894     info = self.extract_info(
#    1895         ie_result['url'], ie_key=ie_result.get('ie_key'),
#    1896         extra_info=extra_info, download=False, process=False)
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1642, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1640             raise ExistingVideoReached
#    1641         break
# -> 1642     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1643 else:
#    1644     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1653, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1651 while True:
#    1652     try:
# -> 1653         return func(self, *args, **kwargs)
#    1654     except (CookieLoadError, DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1655         raise
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/YoutubeDL.py:1788, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1785 self._apply_header_cookies(url)
#    1787 try:
# -> 1788     ie_result = ie.extract(url)
#    1789 except UserNotLive as e:
#    1790     if process:
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/common.py:748, in InfoExtractor.extract(self, url)
#     745 self.initialize()
#     746 self.to_screen('Extracting URL: %s' % (
#     747     url if self.get_param('verbose') else truncate_string(url, 100, 20)))
# --> 748 ie_result = self._real_extract(url)
#     749 if ie_result is None:
#     750     return None
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/youtube/_video.py:3543, in YoutubeIE._real_extract(self, url)
#    3540 base_url = self.http_scheme() + '//www.youtube.com/'
#    3541 webpage_url = base_url + 'watch?v=' + video_id
# -> 3543 webpage, master_ytcfg, player_responses, player_url = self._download_player_responses(url, smuggled_data, video_id, webpage_url)
#    3545 playability_statuses = traverse_obj(
#    3546     player_responses, (..., 'playabilityStatus'), expected_type=dict)
#    3548 trailer_video_id = get_first(
#    3549     playability_statuses,
#    3550     ('errorScreen', 'playerLegacyDesktopYpcTrailerRenderer', 'trailerVideoId'),
#    3551     expected_type=str)
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/youtube/_video.py:3503, in YoutubeIE._download_player_responses(self, url, smuggled_data, video_id, webpage_url)
#    3501     if pp:
#    3502         query['pp'] = pp
# -> 3503     webpage = self._download_webpage_with_retries(webpage_url, video_id, query=query)
#    3505 master_ytcfg = self.extract_ytcfg(video_id, webpage) or self._get_default_ytcfg()
#    3507 player_responses, player_url = self._extract_player_responses(
#    3508     self._get_requested_clients(url, smuggled_data),
#    3509     video_id, webpage, master_ytcfg, smuggled_data)
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/youtube/_base.py:754, in YoutubeBaseInfoExtractor._download_webpage_with_retries(self, retry_fatal, retry_on_status, *args, **kwargs)
#     752 for retry in self.RetryManager(fatal=retry_fatal):
#     753     try:
# --> 754         return self._download_webpage(*args, **kwargs)
#     755     except ExtractorError as e:
#     756         if isinstance(e.cause, network_exceptions):
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/common.py:1194, in InfoExtractor._download_webpage(self, url_or_request, video_id, note, errnote, fatal, tries, timeout, *args, **kwargs)
#    1192 while True:
#    1193     try:
# -> 1194         return self.__download_webpage(url_or_request, video_id, note, errnote, None, fatal, *args, **kwargs)
#    1195     except IncompleteRead as e:
#    1196         try_count += 1
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/common.py:1145, in InfoExtractor.__create_download_methods.<locals>.download_content(self, url_or_request, video_id, note, errnote, transform_source, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#    1143     kwargs.pop('transform_source')
#    1144 # The method is fetched by name so subclasses can override _download_..._handle
# -> 1145 res = getattr(self, download_handle.__name__)(url_or_request, video_id, **kwargs)
#    1146 return res if res is False else res[0]
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/common.py:974, in InfoExtractor._download_webpage_handle(self, url_or_request, video_id, note, errnote, fatal, encoding, data, headers, query, expected_status, impersonate, require_impersonation)
#     972     assert not fatal
#     973     return False
# --> 974 content = self._webpage_read_content(urlh, url_or_request, video_id, note, errnote, fatal,
#     975                                      encoding=encoding, data=data)
#     976 if content is False:
#     977     assert not fatal
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/extractor/common.py:1037, in InfoExtractor._webpage_read_content(self, urlh, url_or_request, video_id, note, errnote, fatal, prefix, encoding, data)
#    1034 def _webpage_read_content(self, urlh, url_or_request, video_id, note=None, errnote=None, fatal=True,
#    1035                           prefix=None, encoding=None, data=None):
#    1036     try:
# -> 1037         webpage_bytes = urlh.read()
#    1038     except TransportError as err:
#    1039         errmsg = f'{video_id}: Error reading response: {err.msg}'
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/yt_dlp/networking/_requests.py:145, in RequestsResponseAdapter.read(self, amt)
#     142 def read(self, amt: int | None = None):
#     143     try:
#     144         # Interact with urllib3 response directly.
# --> 145         return self.fp.read(amt, decode_content=True)
#     147     # See urllib3.response.HTTPResponse.read() for exceptions raised on read
#     148     except urllib3.exceptions.SSLError as e:
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/urllib3/response.py:955, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     952     if len(self._decoded_buffer) >= amt:
#     953         return self._decoded_buffer.get(amt)
# --> 955 data = self._raw_read(amt)
#     957 flush_decoder = amt is None or (amt != 0 and not data)
#     959 if not data and len(self._decoded_buffer) == 0:
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/urllib3/response.py:879, in HTTPResponse._raw_read(self, amt, read1)
#     876 fp_closed = getattr(self._fp, "closed", False)
#     878 with self._error_catcher():
# --> 879     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880     if amt is not None and amt != 0 and not data:
#     881         # Platform-specific: Buggy versions of Python.
#     882         # Close the connection when no data is returned
#    (...)    887         # not properly close the connection in all cases. There is
#     888         # no harm in redundantly calling close.
#     889         self._fp.close()
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/site-packages/urllib3/response.py:862, in HTTPResponse._fp_read(self, amt, read1)
#     859     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     860 else:
#     861     # StringIO doesn't like amt=None
# --> 862     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/http/client.py:467, in HTTPResponse.read(self, amt)
#     464     return b""
#     466 if self.chunked:
# --> 467     return self._read_chunked(amt)
#     469 if amt is not None:
#     470     if self.length is not None and amt > self.length:
#     471         # clip the read to the "end of response"
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/http/client.py:590, in HTTPResponse._read_chunked(self, amt)
#     588 try:
#     589     while True:
# --> 590         chunk_left = self._get_chunk_left()
#     591         if chunk_left is None:
#     592             break
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/http/client.py:573, in HTTPResponse._get_chunk_left(self)
#     571     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     572 try:
# --> 573     chunk_left = self._read_next_chunk_size()
#     574 except ValueError:
#     575     raise IncompleteRead(b'')
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/http/client.py:533, in HTTPResponse._read_next_chunk_size(self)
#     531 def _read_next_chunk_size(self):
#     532     # Read the next chunk size from the file
# --> 533     line = self.fp.readline(_MAXLINE + 1)
#     534     if len(line) > _MAXLINE:
#     535         raise LineTooLong("chunk size")
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/conda_vid_eval/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import re
import requests

def get_channel_id_from_handle(handle_url):
    """
    Attempts to extract the channel ID (UC...) from a YouTube handle page by scraping.
    Returns the channel ID string if found, or None if not found.
    """
    try:
        # Example handle URL: https://www.youtube.com/@Nike
        response = requests.get(handle_url, timeout=10)
        if response.status_code == 200:
            # Look for channelId pattern in the page source
            # YouTube often has a JSON script with: "channelId":"UCXXXX..."
            match = re.search(r'"channelId":"(UC[0-9A-Za-z_\-]+)"', response.text)
            if match:
                return match.group(1)
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {handle_url}: {e}")
    
    return None


channel_urls = [
    "https://www.youtube.com/@Nike",
    "https://www.youtube.com/@adidas",
    "https://www.youtube.com/@CocaCola",
    "https://www.youtube.com/@McDonalds",
    "https://www.youtube.com/@Apple",
    "https://www.youtube.com/@Samsung",
    "https://www.youtube.com/@redbull",
    "https://www.youtube.com/@GoPro",
    "https://www.youtube.com/@Airbnb",
    "https://www.youtube.com/@Uber",
    "https://www.youtube.com/@Netflix",
    "https://www.youtube.com/@disney",
    "https://www.youtube.com/@starbucks",
    "https://www.youtube.com/@Walmart",
    "https://www.youtube.com/@intel",
    "https://www.youtube.com/@amazon",
    "https://www.youtube.com/@Microsoft",
    "https://www.youtube.com/@Sony",
]

for url in channel_urls:
    channel_id = get_channel_id_from_handle(url)
    if channel_id:
        # print(f"{url}  ->  https://www.youtube.com/channel/{channel_id}")
        print(f"'https://www.youtube.com/channel/{channel_id}', #{url}")
    # else:
    #     print(f"{url}  ->  Channel ID not found")
# Out:
# 'https://www.youtube.com/channel/UCNhxq7He5p-_FdBh0OaxcQg', #https://www.youtube.com/@Nike
# 'https://www.youtube.com/channel/UCuLUOxd7ezJ8c6NSLBNRRfg', #https://www.youtube.com/@adidas
# 'https://www.youtube.com/channel/UCbpUSVxiBSjc0CHm0ksuJgw', #https://www.youtube.com/@McDonalds
# 'https://www.youtube.com/channel/UCYFQ33UIPERYx8-ZHucZbDA', #https://www.youtube.com/@Apple
# 'https://www.youtube.com/channel/UCnEdfCdbxJJ9ouWKLSRCRRw', #https://www.youtube.com/@Samsung
# 'https://www.youtube.com/channel/UC8VddvuHJzIj__Ud0rY2_ww', #https://www.youtube.com/@redbull
# 'https://www.youtube.com/channel/UC-WMwOzgFdvvGVLB1EZ-n-w', #https://www.youtube.com/@GoPro
# 'https://www.youtube.com/channel/UC1xnncYc7586km_rIYQLtLQ', #https://www.youtube.com/@Uber
# 'https://www.youtube.com/channel/UCGie8GMlUo3kBKIopdvumVQ', #https://www.youtube.com/@Netflix
# 'https://www.youtube.com/channel/UCIrgJInjLS2BhlHOMDW7v0g', #https://www.youtube.com/@disney
# 'https://www.youtube.com/channel/UC9G8DcGtPfHsVEfUTM_TjEw', #https://www.youtube.com/@intel
# 'https://www.youtube.com/channel/UCxGq825hl0AHP18I9-JGKgg', #https://www.youtube.com/@amazon
# 'https://www.youtube.com/channel/UCnba_sSOe_umiHCpYYvRCqQ', #https://www.youtube.com/@Microsoft
# 'https://www.youtube.com/channel/UCDCIVTeg-_V-xmFV8kAkblg', #https://www.youtube.com/@Sony
